# %% [markdown]
# # Clone & Install package

# %%
# !git clone https://github.com/ChiThang-50Cent/DS200.git
# !pip install -r /content/DS200/requirements.txt

# !npm install localtunnel
# Out:
# fatal: destination path 'DS200' already exists and is not an empty directory.
# 'pip' is not recognized as an internal or external command,
# operable program or batch file.
# 'npm' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !wget https://archive.apache.org/dist/spark/spark-3.0.1/spark-3.0.1-bin-hadoop2.7.tgz
# !apt-get -y install openjdk-8-jdk-headless
# !tar -xzf spark-3.0.1-bin-hadoop2.7.tgz
# !mv spark-3.0.1-bin-hadoop2.7 spark
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.
# tar: Error opening archive: Failed to open 'spark-3.0.1-bin-hadoop2.7.tgz'
# 'mv' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark"

# %%
os.kill(os.getpid(), 9)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 os.kill(os.getpid(), 9)
#
# NameError: name 'os' is not defined

# %% [markdown]
# # Run Streamlit

# %%
# %cd DS200
# !git pull
# !streamlit run /content/DS200/app.py &>/content/logs.txt &
# Out:
# c:\Năm 3\BDS\DS200
# Already up to date.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 3
#       1 get_ipython().run_line_magic('cd', 'DS200')
#       2 get_ipython().system('git pull')
# ----> 3 get_ipython().system('streamlit run /content/DS200/app.py &>/content/logs.txt &')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\zmqshell.py:642, in ZMQInteractiveShell.system_piped(self, cmd)
#     635 if cmd.rstrip().endswith("&"):
#     636     # this is *far* from a rigorous test
#     637     # We do not support backgrounding processes because we either use
#     638     # pexpect or pipes to read from.  Users can always just call
#     639     # os.system() or use ip.system=ip.system_raw
#     640     # if they really want a background process.
#     641     msg = "Background processes not supported."
# --> 642     raise OSError(msg)
# ...

# %% [markdown]
# ```
# Copy IP trong file /content/logs.txt
# ```
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Tunning

# %%
# !npx localtunnel --port 8501
# Out:
# npx: installed 22 in 1.604s
# your url is: https://light-apes-call.loca.lt
# ^C

# %% [markdown]
# ```
# Click vào url được in bên dưới, xuất hiện trang web tunning.
# Nhập IP vào web
# ```
# ![image.png](data:image/png;base64,...)
